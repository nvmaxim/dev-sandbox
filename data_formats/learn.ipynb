# %%
import json 

with open("9.json", "r", encoding="utf-8") as file:
    data = json.load(file)


polygon_name = [feature["properties"]["name"] for feature in data["features"] if feature["geometry"]["type"] == "Polygon"]

print(polygon_name)



with open("9.json", "r", encoding="utf-8") as file:
    data = json.load(file)


polyghon_name = [feature["properties"]["name"] for feature in data["featrues"] if featrue["geometry"]["type"] == "Polygon"]

# %%
import yaml

with open("8.yaml", "r", encoding="utf-8") as file:
    data = yaml.safe_load(file)

host = data["database"]["host"]
port = data["database"]["port"]

print(host, port, sep=", ")

# %%
import yaml
with open("8.yaml", "r", encoding="utf-8") as file:
    config = yaml.safe_load(file)


# print(config)
db_host = config["database"]["host"]
db_port = config["database"]["port"]

print(db_host)
print(db_port)

# %%
import json 

with open("9.json", "r", encoding="utf-8") as file:
    data = json.load(file)

name_polygon = [feature["properties"]["name"] for feature in data["features"] if feature["geometry"]["type"] == "Polygon"]


print(name_polygon)

# %%
import xml.etree.ElementTree as ET

with open ("2.xml", "r", encoding="utf-8") as file:
    tree= ET.parse(file)
    root = tree.getroot()

    result = {"name_track": root.find("Document/name").text, "points": []}

    for placemark in root.find("Document").findall("Placemark"):
        time = placemark.find("timestamp").text
        point_tag = placemark.find("Point")

        result["points"].append({
            "time": time,
            "lat": float(point_tag.attrib.get("lat")),
            "lon": float(point_tag.attrib.get("lon"))
        })


print(result)

# %%
import xml.etree.ElementTree as ET

with open("1.xml", "r", encoding="utf-8") as file:
    tree = ET.parse(file)
    root = tree.getroot()

    result = {"name": root.find("name").text, "location": root.attrib.get("city"), "staff": []}

    for person in root.find("employees").findall("person"):
        result["staff"].append({"name": person.text, "role": person.attrib.get("role")})



print(result)

# %%
import xml.etree.ElementTree as ET

with open ("1.xml", "r", encoding="utf-8") as file:
    tree = ET.parse(file)
    root = tree.getroot()

    result = {"name": root.find("name").text, "location": root.attrib.get("store"), "staff": []}


    for person in root.find("employees").findall("person"):
        result["staff"].append({"name_staff": person.text, "role": person.attrib.get("role") })

print(result)

# %%
import yaml
with open ("8.yaml", "r", encoding="utf-8") as file:
    config = yaml.safe_load(file)

db_host = config["database"]["host"]

print(db_host)

# %%
import json

with open("6.json", "r", encoding="utf-8") as file:
    data = json.load(file)

data["status"] = "processed"

with open("output1.json", "w", encoding="utf-8") as file:
    json.dump(data, file, indent=4, ensure_ascii=False)





    data = json.load()



    json.dump(data, file, indent=4, ensure_ascii=False)

# %%
import json

with open("6.json", "r", encoding="utf-8") as file:
    data = json.load(file)

data["status"] = "processed"

with open("output2.json", "w", encoding="utf-8") as file:
    json.dump(data, file, indent=4, ensure_ascii=False)

print(data)

# %%
import xml.etree.ElementTree as ET

with open("4.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

geojson = {"type": "FeatureCollection", "features": []}

for parcel in root.findall("Parcel"):
    coords = parcel.find("Coordinates")
    lat = float(coords.find("lat").text)
    lon = float(coords.find("lon").text)


    feature = {"type": "Feature", "geometry": {"type": "Point", "coordinates": [lon, lat]}, "properties": {"parcel_id": parcel.attrib.get("id"), "parcel_type": parcel.attrib.get("type"), "price": parcel.find("Price").text}}


geojson["features"].append(feature)
print(geojson)

# %%
import xml.etree.ElementTree as ET

with open("4.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

geojson = {"type": "FeatureCollection", "features": []}

for parcel in root.findall("Parcel"):
    coords = parcel.find("Coordinates")
    lat = coords.find("lat").text
    lon = coords.find("lon").text

    feature = {"type": "Feature", "geometry": {"type": "Point", "coordinates": [lon, lat]}, "properties": {"parcel_id": parcel.attrib.get("id"), "parcel_type": parcel.attrib.get("type"), "price": parcel.find("Price").text}}

geojson["features"].append(feature)

# %%
import xml.etree.ElementTree as ET

with open("2.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

result = {"name": root.find("Document/name").text, "points": []}


for placemark in root.find("Document").findall("Placemark"):
    timestamp = placemark.find("timestamp").text
    point_teg = placemark.find("Point")

    result["points"].append({"time": timestamp, "lon": point_teg.attrib.get("lon"), "lat": placemark})


print(result)

# %%
import xml.etree.ElementTree as ET

with open("4.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

geojson = {"type": "FeatureCollection", "features": []}


for parcel in root.find("Parcel"):
    coords = parcel.find("Coordinates")
    lon = float(coords.find("lon").text)
    lat = float(coords.find("lat").text)

    feature = {"type": "feature", "geometry": {"type": "Point", "coordinates": [lon, lat]}, "properties": {"parcel_id": parcel.attrib.get("id"), "parcel_type": parcel.attrib.get("type"), "price": parcel.find("Price").text}}


geojson["features"].append(feature)

# %%
import xml.etree.ElementTree as ET

with open("2.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

result = {"name": root.find("Document/name").text, "points": []}



for placemark in root.find("Document").findall("Placemark"):
    timestamp = placemark.find("timestamp").text
    coords =placemark.find("Point")


    result["pointes"].append({"time": timestamp, "lon": float(coords.attrib.get("lon"), float(coords.attrib.get("lat")))})

# %%
import xml.etree.ElementTree as ET

with open("5.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()


ns = {"k": "http://www.opengis.net/kml/2.2"}

track_name = root.find("k:Document/k:name", namespaces=ns).text

result = {"track_name": track_name}

print(result)

# %%
import xml.etree.ElementTree as ET

with open("5.xml", "r", encoding="utf-8") as file:
    xml = ET.parse(file)
    root = xml.getroot()

ns = {"k": "http://www.opengis.net/kml/2.2"}

track_name = root.find("k:Document/k:name", namespaces=ns).text

result = {"track_name": track_name}

# %%
import json

with open("9.json", "r", encoding="utf-8") as data:
    data = json.load(data)

polygon_name = [feature["properties"]["name"] for feature in data["features"] if feature["geometry"]["type"] == "Polygon"]


print(data)

# %%
import json

with open("9.json", "r", encoding="utf-8") as data:
    data = json.load(data)


result = [feature["properties"]["name"] for feature in data["features"] if feature["geometry"]["type"] == "Polygon"]


print(result)

# %%
import xml.etree.ElementTree as ET

with open("2.xml", "r", encoding="utf-8") as file:
    tree = ET.parse(file)
    root = tree.getroot()

result = {"track_name": root.find("Document/name").text, "points": []}

for placemark in result.find("Document").findall("Placemark"):
    timestamp = placemark.find("timestamp").text
    points = placemark.find("Point")

    result["points"].append({"time": timestamp, "lon": float(points.attrib.get("lon")), "lat": float(points.attrib.get("lat"))})


print(result)

# %%
import json

with open("6.json", "r", encoding="utf-8") as file:
    data = json.load(file)

data["status"] = "processed"

print(data)

# %%
geojson_dict = {
    "type": "Feature",
    "properties": {"city": "Москва"}
}


data = json.dumps(geojson_dict, indent=4, ensure_ascii=False)

print(data)

# %%
import xml.etree.ElementTree as ET

with open("2.xml", "r", encoding="utf-8") as file:
    tree = ET.parse(file)
    root = tree.getroot()


active_stations = []

for station in root.findall("station"):
    if station.attrib.get("status") == "active":
        active_stations.append({"station_id": station.attrib.get("id"), })
        pass

# %%
import xml.etree.ElementTree as ET

with open("2.xml", "r", encoding="utf-8") as file:
    tree = ET.parse(file)
    root = tree.getroot()


active_stations = []

for station in root.findall("station"):
    if station.attrib.get("status") == "active":
        active_stations.append({"station_id": station.attrib.get("id"), station})

# %%
import json


with open("3_raw_polygons.json", "r", encoding="utf-8") as file:
    data = json.load(file)


print(data)
