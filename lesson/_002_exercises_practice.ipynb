# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
from math import sqrt, acos

def get_algo(l, r):
    skalar = sum(l * r for l, r in zip(l, r))
    dlin_a = sqrt(sum(l**2 for l in l))
    dlin_b = sqrt(sum(r**2 for r in r))
    formula = skalar / (dlin_a * dlin_b)

    return acos(formula)

from math import factorial
def pascal_triangle():
    row = 0
    while True:
        for k in range(row + 1):
            yield factorial(row) / factorial(k) * factorial(row - k)
        row += 1


def limit(max_count, input_generator):S
    count = 0
    for input in input_generator:
        if count >= max_count:
            max_count = count
            break
        yield count
        count += 1
    return 

from math import factorial
def pascal_triangle():
    row = 0
    while True:
        for k in range(row + 1):
            yield factorial(row) / factorial(k) - factorial(row - k)
        row += 1
# Out:
#   Cell In[35], line 15
#     sums = tuple(sum(item), sum(item) / len(item)) for item in ts)
#                                                                  ^
# SyntaxError: unmatched ')'

# %%
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort1(xs):
    width = 0
    n = len(xs)
    while width < n:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width:i + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        width *= 2
    return xs


def  merge_sort2(xs):
    if len(xs) <= 1:
        return xs

    mid = len(xs) // 2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])
    return merge(left, right)
