# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# import pandas 

# df = df[df["department"].isin(["А", "Б"])].groupby("department").agg({"revenue": "mean"}).rename(columns={"revenue": "revenue_avg"}).sort_values("revenue_avg", ascending=False).reset_index()

# print(df)


def ackermann(n, m):
    if hasattr(ackermann, "calls"):
        ackermann.calls = 0
    ackermann.calls += 1

    if n == 0:
        return m + 1
    elif n >= 0 and m == 0:
        return ackermann(n, n - 1)
    else:
        return ackermann(n - 1, ackermann(n - 1, m))


def is_prime(n):
    try:
        n = float(int(n))
    except (TypeError, ValueError):
        return False
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 3
#       1 import pandas
# ----> 3 df = df[df["department"].isin(["А", "Б"])].groupby("department").agg({"revenue": "mean"}).rename(columns={"revenue": "revenue_avg"}).sort_values("revenue_avg", ascending=False).reset_index()
#       5 print(df)
#
# File ~/Projects/dev-sandbox/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# ...

# %%
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(left[j:])
    return result

def merge_sort1(xs):
    width = 0
    n = len(xs)
    while True:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        width *=2
    return xs

def merge_sort2(xs):
    if len(xs) <= 1:
        return False
    mid = len(xs) //2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])
    return merge(left, right)
    pass

def limit(max_count, input_generator):
    count = 0
    for item in input_generator:
        if count >= max_count:
            max_count = item
            break
    yield item
    count += 1
