# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# Вопрос: Превратить вложенный список (1 уровень) в плоский.

# Пример input_list:
input_list = [0, [1, 2], 4, [1, 0, 3]]

output = []
# for item in input_list:
#     if isinstance(item, list):
#         output.extend(item)
#     else:
#         output.append(item)



print(output)
# Out:
# [0, 1, 2, 4, 1, 0, 3]
