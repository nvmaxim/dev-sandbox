# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
import inspect

# tests for foo function для тестирования
# 1. Создаем тестовую функцию со всеми типами аргументов
def my_sample_function(a, b=42, *args, c, d=100, **kwargs):
    """
    Это тестовая функция для демонстрации работы inspect_function.
    Она принимает позиционные, именованные аргументы, args и kwargs.
    """
pass



def inspect_func(func):
    print(f"name func {func.__name__}")

    doc = inspect.getdoc(func)
    print(f"doc {doc if doc else ""}")

    params = inspect.signature().parameters

    posonly = []
    posorkey = []
    keyonly = []
    vararg, varkwargs = None, None
    defarg, defkwagr = [], []

    for name, param in params.items():
        if param.kind == param.POSTIONAL_ONLY:
            posonly.append(name)
        elif param.kind == param.POSITIONAL_OR_KEYWORD:
            posorkey.append(name)
            if param.default != param.empty:
                defarg.append(f"{name}{param.defalut}")
        elif param.kind == param.KEYWORD_ONLY:
            keyonly.append(name)
            if param.default != param.empty:
                defkwagr.append(f"{name}{param.default}")
        elif param.kind == param.VAR_POSITIONAL:
            vararg = name
        elif param.kind == param.VAR_KEYWOED:
            varkwargs = name


print(f"args peerd func {", ".join(params.keys(()))}")
print(f"only pos {", ".join(posonly)}")
print(f"pos or key {", ".join(posorkey)}")
print(f"name apraman {", ".join(keyonly)}")
print(f"name for args {varargs if varargs else ""}")
print(f"name for kwargs {varkwargs if varkwargs esle ""}")
print(f"default args {", ".join(defaults)}")
print(f"default kwargs {", ".join(defaultkwargs)}")





















# def inspect_func(func):
#     print(f"name func {func.__name__}")

#     doc = inspect.doc(func)
#     print(f"doc func {doc if doc else ""}")

#     params = inspect.signature(func).parameters

#     pos_only = []
#     pos_or_key = []
#     key_only = []
#     var_arg, var_kwargs = None, None
#     default, default_kwargs = [], []

#     for name, param in params.items():
#         if param.kind == param.POSITIONAL_ONLY:
#             pos_only.append(name)
#         elif param.kind == param.POSITIONAL_OR_KEYWORD:
#             pos_or_key.append(name)
#             if param.default != param.empty:
#                 default.append(f"{name}{param.default}")
#         elif param.kind == param.KEYWORD_ONLY:
#             key_only.append(name)
#             if param.default != param.empty:
#                 default_kwargs.append(f"{name}{param.default}")
#         elif param.kind == param.VAR_KEYWORD:
#             var_arg = name
#         elif param.kind == param.VAR_POSITIONAL:
#             var_kwargs = name

# print(f"args func {f", ".join(params.keys(()))}")
# print(f"pos only {", ".join(pos_only)}")
# print(f"pos or key {", ".join(pos_or_key)}")
# print(f"key word only {", ".join(key_only)}")
# print(f"name of args {var_arg if var_arg else ""}")
# print(f"name for kwargs {var_kwargs if var_kwargs else ""}")
# print(f"def arg {f", ".join(defaults)}")
# print(f"def kwargs {f", ".join(default_kwargs)}")

         



















# def inspect_function(func):
#     print(f"name func {func.__name__}")

#     doc = inspect.getdoc(func)
#     print(f"documentatons {doc if doc else "doc no"}")

#     params = inspect.signature(func).parameters

#     positional_only = []
#     positional_or_keyword = []\
#     keyword_only = []
#     var_args, var_kwargs = None, None
#     defaults, defaults_kwargs = [], []

#     for name, param in params.items():
#         if param.kind == param.POSITIONAL_ONLY:
#             positional_only.append(name)
#         elif param.kind == param.POSITIONAL_OR_KEYWORD:
#             positional_or_keyword.append(name)
#             if param.default != param.empty:
#                 defaults.append(f"{name}{param.default}")
#         elif param.kind == param.KEYWORD_ONLY:
#             keyword_only.append(name)
#             if param.default != param.empty:
#                 defaults_kwargs.append(f"{name}{param._default}")
#         elif param.kind == param.VAR_POSITIONAL:
#             var_args = name
#         elif param.kind == param.VAR_KEYWORD:
#             var_kwargs = name


# print(f" аргументы принимаемые функцией {", ".join(params.keys(()))}")
# print(f"strogo positionals: {", ".join(postional_only)}")
# print(f"positional or keywords: {", ".join(positional_or_keyword)}")
# print(f"strogo names : {", ".join(keywords_only)}")
# print(f" args : {var_args if var_args else ""}")
# print(f" kwargs: {var_kwargs if var_kwargs else ""}")
# print(f" defaults args {", ".join(defaults)}")
# print(f" defaults kwargs {", ".join(default_kwargs)}")

# %%
# def merge (left, right):
#     result = []
#     i = j = 0

#     while i < len(left) and j < len(right):
#         if left[i] < right[j]:
#             result.append(left[i])
#             i += 1
#         else:
#             result.append(right[j])
#             j += 1
#     result.extend(left[i:])
#     result.extend(right[j:])
#     return result

# def merge_sort1(xs):
#     width = 1
#     n = len(xs)
#     while width < n:
#         for i in range(0, n, 2 * width):
#             left = xs[i:i + width]
#             right = xs[i + width:i + 2 * width]
#             xs[i:i + 2 * width] = merge(left, right)
#         width *= 2
#     return xs

# def merge (left, right):
#     result = []
#     i = j = 0

#     while i < len(left) and j < len(right):
#         if left[i] < right[j]:
#             result.append(left[i])
#             i += 1
#         else:
#             result.append(right[j])
#             j += 1
#     result.extend(left[i:])
#     result.extend(right[i:])
#     return result

# def merge_sort1(xs):
#     width = 1
#     n = len(xs)
#     while width < n:
#         for i in range(0, n, 2 * width):
#             left = xs[i:i * width]
#             right = xs[i + width:i + 2 * width]
#             xs[i:i + 2 * width] = merge(left, right)
#         width *= 2
#     return xs 

# def merge_sort2(xs):
#     if len(xs) <= 1:
#         return xs
    
#     mid = len(xs) // 2
#     left = merge_sort2(xs[:mid])
#     right = merge_sort2(xs[mid:])

#     return merge(left, right)
        






# def merge (left, right):
#     result = []
#     i = j = o

#     while i < len(left) and j < len(right):
#         if left[i] < right[j]:
#             result.append(left[i])
#             i += 1
#         else:
#             result.append(right[j])
#             j += 1
#     result.extend(left[i])
#     result.extend(right[j])
#     return result

# def merge_sort1(xs):
#     width = 1
#     n = len(xs)
#     while width < n:
#         for i in range(0, n, 2 * width):
#             left = xs[i:i * width]
#             right = xs[i * width:i + 2 * width]
#             xs[i:i + 2 * width] = merge(left, right)
#         width *= 2
#     return xs

# def merge_sort2(xs):
#     if len(xs) <= 1:
#         return xs
    
#     mid = len(xs) // 2
#     left = merge_sort2(xs[:mid])
#     right = merge_sort2(xs[mid:])

#     return merge(left, right)




# def merge(left, right):
#     result = []
#     i = j = 0

#     if i < len(left) and j < len(right):
#         if left[i] < right[j]:
#             result.appent(left[i])
#             i +=1
#         else:
#             result.append(right[j])
#             j += 1
#     result.extend(left[i:])
#     result.extend(right[j:])
#     return result


# def merge_sort1(xs):
#     width = 1
#     n = len(xs)
#     while width < n:
#         for i in range(0, n, 2 * width):
#            left = xs[i:i * width]
#            right = xs[i * width:i + 2 * width]
#            xs[i:i + 2 * width] = merge(left, right)
#         xs *= 2
#     return xs
        
#     pass

# def merge_sort2(xs):
#     if len(xs) <= 1:
#         return False
    
#     mid = len(xs) // 2
#     left = merge_sort2(xs[mid:])
#     right = merge_sort2(xs[:mid])

#     return  merge(left, right)

    


def merge(left, right):
    result = []
    i = j = 0

    if i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort1(xs):
    width = 1
    n = len(xs)
    while width < n:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width:i + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        xs *= 2
    return xs


    pass

def merge_sort2(xs):
    if len(xs) <= 1:
        return False
    
    mid = len(xs) // 2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])


    return merge(left, right)












           
# assert merge_sort2([1, 2, 3, 4, 5, 6]) == [1, 2, 3, 4, 5, 6], "test 1"
# assert merge_sort2([6, 1, 2, 3, 4, 5, 6]) == [1, 2, 3, 4, 5, 6, 6], "test 2"
# assert merge_sort2([3,1,4,1,5,9,2,6,5,3,5]) == [1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 9], "test 3")
# Out:
#   Cell In[2], line 90
#     right = xs[]
#                ^
# SyntaxError: invalid syntax

# %%
# 3.2_Задание: Векторная математика (Угол между векторами)
# Сторона А (Вопрос): Задача: Найти угол между двумя n-мерными векторами в радианах.
# Указания:
# Векторы — это списки left и right.
# Использовать формулу:​
# Где a⋅b — скалярное произведение,
#  а ∣a∣ — длина (норма) вектора.
from math import sqrt, acos

def vector_angle(l, r):
    dot_val = sum((l * r) for l, r in zip(l, r))
    len_a = sqrt(sum(l**2 for l in l))
    len_b = sqrt(sum(l**2 for r in r))

    cos_t = dot_val / (len_a * len_b)

    return acos(cos_t)  



print(f"Тест 1 (45°): {vector_angle([1, 0, 1], [0, 0, 1]):.5f}")
print(f"Тест 2 (90°): {vector_angle([1, 0], [0, 1]):.5f}")
print(f"Тест 3 (0°):  {vector_angle([5, 5], [5, 5]):.5f}")

# %%
# Условие: На вход функции matrix подаётся число N. Функция возвращает матрицу-спираль, закрученную против часовой стрелки, размера NxN. Пример для 3х3:


def matrix (n):
    mat = [[0] * n for _ in range(n)]

    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]

    curr_dir = 0

    y, x = 0, 0

    for num in range(1, n * n + 1):
        mat[y][x] = num
        dy, dx = directions[curr_dir]
        new_y, new_x = y + dy, x + dx

        if not (0 <= new_y < n and 0 <= new_x < n and mat[new_y][new_y] == 0):
            curr_dir = (curr_dir + 1) % 4
            dy, dx = directions[curr_dir]
            new_y, new_x = y + dy, x + dx
        

        y, x = new_y, new_x
    return mat
