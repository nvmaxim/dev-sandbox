# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
def all_elements(xs):
    for x in xs:
        if isinstance(x, list):
            yield all_elements(x)
        else:
            yield x
# Out:
# [('bob2', 20), ('bob3', 20), ('alice', 10), ('bob1', 20), ('bertha', 20), ('david', 0), ('alic', 10), ('chris', 0)]
# [(-20, 'bob2'), (-20, 'bob3'), (-10, 'alice'), (-20, 'bob1'), (-20, 'bertha'), (0, 'david'), (-10, 'alic'), (0, 'chris')]
# [('bob2', 20), ('bob3', 20), ('alice', 10), ('bob1', 20), ('bertha', 20), ('david', 0), ('alic', 10), ('chris', 0)]

# %%
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort1(xs):
    width = 0
    n = len(xs)
    while width < n:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width:i + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        width *= 2
    return xs


def  merge_sort2(xs):
    if len(xs) <= 1:
        return xs

    mid = len(xs) // 2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])
    return merge(left, right)
# Out:
# [(1, 11, 121, 1331, 121, 11, 1), (2, 21, 231, 2541, 231, 21, 2), (3, 31, 341, 3751, 341, 31, 3), (4, 41, 451, 4961, 451, 41, 4)]
# (10, 104, 1144, 12584, 1144, 104, 10)
# (2.5, 26.0, 286.0, 3146.0, 286.0, 26.0, 2.5)
