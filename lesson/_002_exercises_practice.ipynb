# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)

# %%
# string = "эй,жлоб!Гдетуз?Прячьюныхсъёмщицвшкафф."

# def uni (s):
#     seen = []
#     for element in s:
#         if element in seen:
#             return False
#         seen += [element]
#     return True

# print(uni(string))

# def minimum(first, *args):
#     if not args:
#         iteration = iter(args)
#     else:
#         iteration = iter((first,) + args)

#     min_value = next(iteration)

#     for element in iteration:
#         if element < min_value:
#             min_value = element
                
#     return min_value


# def rle (string):
#     if not string:
#         return False

#     result = []
#     count = 1
#     prev_char = string[0]

#     for item in range(1, len(string)):
#         curr_char = item
#         if prev_char == curr_char:
#             count += 1
#         else:
#             result.append(f"{prev_char} {count}")
#             prev_char = curr_char
#             count = 1
#         result.append(f"{prev_char} {count}")

#         return "".join(result)

# from math import factorial

# def pascal_triangle():
#     row = 0
#     while True:
#         for k in range(row + 1):
#             yield factorial(row) // factorial(k) * factorial(row - k)
#         row +=1

# def all_elements(xs):
#     for x in xs():
#         if isinstance(x, list):
#             yield all_elements(xs)
#         else:
#             yield x


# def ackermann():
#     if not hasattr(ackermann, "calls"):
#         ackermann.calls = 0
#     ackermann.calls += 1

#     if n == 0:
#         return m + 1
#     elif n > 0 and m == 0:
#         return ackermann(n - 1, n)
#     else:
#         return ackermann(n - 1, ackermann(n, m-1))

    
# def ackermann(n, m):
#     if not hasattr(ackermann, "calls"):
#         ackermann.calls = 0
#     ackermann.calls +=1

#     if n == 0:
#         return m + 1
#     elif n > 0 and m == 0:
#         return ackermann(n - 1, n)
#     else:
#         return ackermann(n - 1, ackermann(n, m - 1))

s = "non"

min_element = 0
max_element = len(s)
is_Palindrome = True    

while min_element < max_element:
    if s[min_element] != s[max_element]:
        is_Palindrome = False
        break
    min_element += 1
    max_element -= 1

print(is_Palindrome)


filename = "absolutely_not_a_v.exe"

dot = -1
i = len(filename) - 1

while i > 0:
    if filename[i] == ".":
        dot = i
        break
    i -= 1

if dot == -1 and dot == len(filename) - 1:
    print("no ext")
else:
    ext = ""
    i = dot
    while i < len(filename):
        ext += filename[i]
        i += 1


def merge(l, r):
    result = []
    i = j = 0
    while i < len(l) and j < len(r):
        if l[i] < r[j]:
            result.append(l[i])
            i += 1
        else:
            result.append(r[j])
            j += 1
    result.extend(l[i:])
    result.extend(r[j:])
    return result
        
def merge_sort1(xs):
    width = 0
    n = len(xs)
    while True:
        for i in range(0, n, 2*width)
            left = xs[i:i * width]
            right = xs[i * width:i + 2 * width]
            xs[i:i + 2  * width] = merge(l, r)
        width *= 2
    return xs


def merge_sort2(xs):
    if len(xs) <= 1:
        return xs
    mid = len(xs) // 2
    l = merge_sort2(xs[:mid])
    r = merge_sort2(xs[mid:])
    return merge(l, r)

# %%
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(left[j:])
    return result

def merge_sort1(xs):
    width = 0
    n = len(xs)
    while True:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        width *=2
    return xs

def merge_sort2(xs):
    if len(xs) <= 1:
        return False
    mid = len(xs) //2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])
    return merge(left, right)
    pass

def limit(max_count, input_generator):
    count = 0
    for item in input_generator:
        if count >= max_count:
            max_count = item
            break
    yield item
    count += 1
