# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
n = 4

for x in range(n**2):
    binary  = bin(x)[:2].zfill(n)
    print(f"{binary} - {x}")


def all_elements(xs):
    for x in xs:
        if isinstance(x, list):
            yield all_elements(x)
        else:
            yield x


import inspect

def inspect_function(func):
    print(f"имя функции {func.__name__}")
    doc = inspect.getdoc()
    print(f"документация функции {doc if doc else ""}")

    params = inspect.signature(func).parameters

    posonly = []
    pos_or_key = []
    keyonly = []
    var_args, var_kwargs = None, None
    defargs, defkwargs = [], []

    for name, param in param.items():
        if param.kind == param.POSITIONAL_ONLY:
            posonly.append(name)
        elif param.kind == param.POSITIONAL_OR_KEYWORD:
            pos_or_key.append(name)
            if param.default != param.empty:
                defargs.append(f"{name}{param.default}")
        elif param.kind == param.KEYWORD_ONLY:
            keyonly.append(name)
            if param.default != param.empty:
                defkwargs.append(f"{name}{param.default}")
        elif param.kind == VAR_POSITIONAL:
            var_args = name
        elif param.kind == VAR_KEYWORD:
            var_kwargs = name

print(f"аргументы принимаемые функцией {"".join(params.keys())}")
print(f"pos only {"".join(posonly)}")
print(f"keyor pos {"".join(pos_or_key)}")
print(f"keyonly {"".join(keyonly)}")
print(f"имя для args {var_args if var_args else ""}")
print(f"имя для kwargs {var_kwargs if kwagrs else ""}")
print(f"def args {"".join(defargs)}")    
print(f"def args {"".join(defkwarts)}")
# Out:
#   Cell In[9], line 51
#     print(f"имя для args {var_args if var_args else }")
#                                    ^
# SyntaxError: f-string: expecting '=', or '!', or ':', or '}'

# %%
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort1(xs):
    width = 0
    n = len(xs)
    while width < n:
        for i in range(0, n, 2 * width):
            left = xs[i:i * width]
            right = xs[i * width:i + 2 * width]
            xs[i:i + 2 * width] = merge(left, right)
        width *= 2
    return xs


def  merge_sort2(xs):
    if len(xs) <= 1:
        return xs

    mid = len(xs) // 2
    left = merge_sort2(xs[:mid])
    right = merge_sort2(xs[mid:])
    return merge(left, right)
