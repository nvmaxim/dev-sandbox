# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# УПРАЖНЕНИЕ 2: "Классификация клиентов (python)
# Классифицируйте клиентов по уровню выручки на VIP, Standard и Basic. Найдите всех VIP-клиентов и отсортируйте их по убыванию выручки.

import pandas as pd
import numpy as np

df["category"] = np.where(df["revenue"] > 20000, "VIP", np.where(df["revenue"] > 10000, "Standard", "Basic"))


# result = df[df""]
print(df)
# Out:
#   manager department  revenue  experience period  category
# 0    Иван          А    15000           2     Q1  Standard
# 1   Мария          Б    22000           5     Q1       VIP
# 2    Петр          А    17000           3     Q1  Standard
# 3    Анна          В    12000           1     Q1  Standard
# 4  Сергей          Б    25000           4     Q1       VIP
# 5    Иван          А    18000           2     Q2  Standard
# 6   Мария          Б    19000           5     Q2  Standard
# 7    Анна          В    14000           1     Q2  Standard
# 8   Ольга          А    16000           2     Q2  Standard
