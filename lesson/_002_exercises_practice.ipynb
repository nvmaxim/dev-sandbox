# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# Вопрос по задаче (Задача 6)
# Условие: Напишите функцию Аккермана, которая дополнительно в атрибуте calls считает, сколько раз ее вызвали. Разрешено использовать hasattr.
# [...]


# ackermann.calls = 0
# result = ackermann(3, 4)

def ackerman(n , m):
    if not hasattr(ackerman, "calls"):
        ackerman.calls = 0
    ackerman.calls += 1

    if n == 0:
        return m + 1
    elif n > 0 and m == 1:
        return ackerman(1 , n -1)
    else:
        return ackerman(n - 1, ackerman(n, m - 1))
    


print(f"--- Финальная проверка ---")
print(f"Математический результат: {result}") # Должно быть 125
print(f"Всего рекурсивных вызовов: {ackermann.calls}") # Должно быть 10359
# Out:
# 2w3w4w5w6w6w1b1b1w2w3w4w5w6w6w1b2b3b3b1w2w3w4w5w6w7w8w9w10w10w1b
# 2a3a3a1b2b
