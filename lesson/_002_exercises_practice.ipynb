# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)

# %%
# УПРАЖНЕНИЕ 1: "Анализ эффективности менеджеров (python)
# В каком отделе (А или Б) менеджеры в среднем приносят больше выручки?


import numpy as np
import pandas as pd

df = df[df["department"].isin(["А", "Б"])].agg({"revenue", "mean"}).rename(columns={"revenue": "avg_revenue"}).sort_values("avg_revenue", ascending=True).reset_index()p
print(result)
# Out:
#             revenue_total
# department
# А                   66000
# Б                   66000
# В                   26000
