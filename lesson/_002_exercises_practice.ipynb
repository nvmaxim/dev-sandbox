# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# Вопрос: Напечатайте таблицу всех двоичных чисел длины n и соответствующие им десятичные числа.
# n = 4 # Заданная длина
# Пример для n = 2:

n = 2

for x in range(2**n):
    binary = bin(x)[:2].zfill(n)
    print(f"{binary} {x}")



filename = "absolutely_not_a_virus.exe"

dot_index = -1
i = len(filename) - 1

while i >= 0:
    if filename[i] == ".":
        dot_index = i
        break
    i -= 1


if dot_index == -1 or dot_index == filename(i) - 1:
    print("no ext")
else:
    ext = ""
    i = dot_index
    while i < len(dot_index):
        ext += filename[i]
        i += 1
    print(ext)
# Out:
# 0b 0
# 0b 1
# 0b 2
# 0b 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 25
#      21         break
#      22     i -= 1
# ---> 25 if dot_index == -1 or dot_index == filename(i) - 1:
#      26     print("no ext")
#      27 else:
#
# TypeError: 'str' object is not callable
